# %%
import pandas as pd
import numpy as np

# %%
#데이터 불러오기
df=pd.read_excel("C:/workspace/프로젝트/기념품샵_목록.xlsx")
df.head()
# Out:
#    Column1 Column2                                            Column3  \
# 0        0    바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...
# 1        1    바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...
# 2        2    바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...
# 3        3    바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...
# 4        4    바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...
#
#        Column4                                            Column5  \
# 0  width:100%;  매장도 깨끗하고 상품도 다양하네요. 열쇠고리나 일반 책갈피도 기본 만원 이상이라서 ...
# 1   width:20%;    핸드메이드 제품은 많음근데 과자 여기서 사지말고 시장가서 사시길저도 알고싶지않았음^^
# 2   width:80%;                                  재밌고 흥미로운 아이템  많던곳
# 3  width:100%;                                                NaN
# 4   width:80%;                                            종류가 많음.
#
#                     Column6
# 0  blog.naver.com/byjeju365
# 1  blog.naver.com/byjeju365
# 2  blog.naver.com/byjeju365
# 3  blog.naver.com/byjeju365
# 4  blog.naver.com/byjeju365

# %%
#불필요한 컬럼 삭제
df.drop(columns=['Column1'], inplace=True) #원본에 그대로 적용
df
# Out:
#                   Column2                                            Column3  \
# 0                    바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...
# 1                    바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...
# 2                    바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...
# 3                    바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...
# 4                    바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...
# ...                   ...                                                ...
# 2242              한라산기프트몰  제주특별자치도 제주시\n                진동로1길 24\n       ...
# 2243     Bakeshirts Store  제주특별자치도 제주시 조천읍\n                대흘2길 1\n     ...
# 2244                 귤아주망  제주특별자치도 서귀포시 대정읍\n                영서중로13번길 11\...
# 2245  공중전화 서귀포약천사 기념품판매점옆  제주특별자치도 서귀포시\n                이어도로 293-28\n   ...
# 2246                 꿈팩토리  제주특별자치도 제주시\n                다랑곶2길 50\n       ...
#
#           Column4                                            Column5  \
# 0     width:100%;  매장도 깨끗하고 상품도 다양하네요. 열쇠고리나 일반 책갈피도 기본 만원 이상이라서 ...
# 1      width:20%;    핸드메이드 제품은 많음근데 과자 여기서 사지말고 시장가서 사시길저도 알고싶지않았음^^
# 2      width:80%;                                  재밌고 흥미로운 아이템  많던곳
# 3     width:100%;                                                NaN
# 4      width:80%;                                            종류가 많음.
# ...           ...                                                ...
# 2242  width:100%;  문의 드리고 할 때마다 이것저것 꼼꼼하게 잘 알려주시고, 가겨도 다른 곳이랑 비교해...
# 2243  width:100%;                                           느낌이가 조아요
# 2244         none                                               none
# 2245  width:100%;                  생각지 않게 수월관음도 감상 할 수 있어  무척 좋았습니다.
# 2246         none                                               none
#
#                              Column6
# 0           blog.naver.com/byjeju365
# 1           blog.naver.com/byjeju365
# 2           blog.naver.com/byjeju365
# 3           blog.naver.com/byjeju365
# 4           blog.naver.com/byjeju365
# ...                              ...
# 2242                  jejuhongbo.com
# 2243  instagram.com/bakeshirts_store
# 2244                            none
# 2245                            none
# 2246      www.instagram.com/ggumaker
#
# [2247 rows x 5 columns]

# %%
#컬럼명 변경
df.rename(columns={'Column2':'이름'}, inplace=True)
df.rename(columns={'Column3':'주소'}, inplace=True)
df.rename(columns={'Column4':'별점'}, inplace=True)
df.rename(columns={'Column5':'리뷰'}, inplace=True)
df.rename(columns={'Column6':'홈페이지'}, inplace=True)

# %%
df.head(10)
# Out:
#      이름                                                 주소           별점  \
# 0  바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...  width:100%;
# 1  바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...   width:20%;
# 2  바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...   width:80%;
# 3  바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...  width:100%;
# 4  바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...   width:80%;
# 5  바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...  width:100%;
# 6  바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...   width:80%;
# 7  바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...   width:80%;
# 8  바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...  width:100%;
# 9  바이제주  제주특별자치도 제주시\n                서해안로 626\n       ...  width:100%;
#
#                                                   리뷰                      홈페이지
# 0  매장도 깨끗하고 상품도 다양하네요. 열쇠고리나 일반 책갈피도 기본 만원 이상이라서 ...  blog.naver.com/byjeju365
# 1    핸드메이드 제품은 많음근데 과자 여기서 사지말고 시장가서 사시길저도 알고싶지않았음^^  blog.naver.com/byjeju365
# 2                                  재밌고 흥미로운 아이템  많던곳  blog.naver.com/byjeju365
# 3                                                NaN  blog.naver.com/byjeju365
# 4                                            종류가 많음.  blog.naver.com/byjeju365
# 5                                                NaN  blog.naver.com/byjeju365
# 6  해안가도로를 따라 용두암으로 향하던 도중에 접했는데...아기자기한 소품들과 더불어서...  blog.naver.com/byjeju365
# 7  제주소품 선물가게로는 규모가 상당히 큰편입니다.이것저것 없는게 없는..2층에는 바다...  blog.naver.com/byjeju365
# 8  야간에 방문했는데 정말 소품 볼 것 많음. 아기자기하고 귀여운 것들이 많음. 자그마...  blog.naver.com/byjeju365
# 9  다양한 작가들의 여행기념품들이 모여있어서 좋았고,제주도만의 먹거리 기념품들도 종류별...  blog.naver.com/byjeju365

# %%
df['주소'] = df['주소'].str.replace('\n', ' ')
df['주소']
# Out:
# 0       제주특별자치도 제주시                 서해안로 626          ...
# 1       제주특별자치도 제주시                 서해안로 626          ...
# 2       제주특별자치도 제주시                 서해안로 626          ...
# 3       제주특별자치도 제주시                 서해안로 626          ...
# 4       제주특별자치도 제주시                 서해안로 626          ...
#                               ...
# 2242    제주특별자치도 제주시                 진동로1길 24          ...
# 2243    제주특별자치도 제주시 조천읍                 대흘2길 1        ...
# 2244    제주특별자치도 서귀포시 대정읍                 영서중로13번길 11  ...
# 2245    제주특별자치도 서귀포시                 이어도로 293-28      ...
# 2246    제주특별자치도 제주시                 다랑곶2길 50          ...
# Name: 주소, Length: 2247, dtype: object

# %%
df['주소']=df['주소'].str.replace('                 ', ' ')

# %%
split_addr=df['주소'].str.split("(", expand=True) #분할된 결과를 여러 열로 확장하여 반환
split_addr
# Out:
#                                    0        1
# 0             제주특별자치도 제주시 서해안로 626    우)63150
# 1             제주특별자치도 제주시 서해안로 626    우)63150
# 2             제주특별자치도 제주시 서해안로 626    우)63150
# 3             제주특별자치도 제주시 서해안로 626    우)63150
# 4             제주특별자치도 제주시 서해안로 626    우)63150
# ...                              ...      ...
# 2242          제주특별자치도 제주시 진동로1길 24    우)63289
# 2243      제주특별자치도 제주시 조천읍 대흘2길 1 2층   우)63343
# 2244  제주특별자치도 서귀포시 대정읍 영서중로13번길 11    우)63510
# 2245      제주특별자치도 서귀포시 이어도로 293-28    우)63543
# 2246        제주특별자치도 제주시 다랑곶2길 50 1층   우)63096
#
# [2247 rows x 2 columns]

# %%
#기존 df에 새로운 열로 추가
df['주소3'] = split_addr[1]
df['주소'] = split_addr[0]

# %%
#불필요한 컬럼 삭제
df.drop(columns=['주소3'], inplace=True) #원본에 그대로 적용

# %%
#index를 포함하지 않고 데이터 저장
df.to_csv("제주도 기념품샵 목록.csv", index=False)

# %%
#데이터 불러오기
df=pd.read_csv("./제주도 기념품샵 목록.csv")
df.head()
# Out:
#      이름                      주소           별점  \
# 0  바이제주  제주특별자치도 제주시 서해안로 626    width:100%;
# 1  바이제주  제주특별자치도 제주시 서해안로 626     width:20%;
# 2  바이제주  제주특별자치도 제주시 서해안로 626     width:80%;
# 3  바이제주  제주특별자치도 제주시 서해안로 626    width:100%;
# 4  바이제주  제주특별자치도 제주시 서해안로 626     width:80%;
#
#                                                   리뷰                      홈페이지
# 0  매장도 깨끗하고 상품도 다양하네요. 열쇠고리나 일반 책갈피도 기본 만원 이상이라서 ...  blog.naver.com/byjeju365
# 1    핸드메이드 제품은 많음근데 과자 여기서 사지말고 시장가서 사시길저도 알고싶지않았음^^  blog.naver.com/byjeju365
# 2                                  재밌고 흥미로운 아이템  많던곳  blog.naver.com/byjeju365
# 3                                                NaN  blog.naver.com/byjeju365
# 4                                            종류가 많음.  blog.naver.com/byjeju365

# %%
df['별점'].replace(['width:100%;', 'width:80%;', 'width:60%;', 'width:40%;', 'width:20%;', 'none'],
              ['5', '4', '3', '2', '1', ''], inplace=True)

df['리뷰'].replace(['none'],[''], inplace=True) #none -> 공백
df['리뷰'] = df['리뷰'].replace('none', '')

df['홈페이지'].replace(['none'],[''], inplace=True)

#별점, 리뷰, 홈페이지 컬럼의 빈 부분을 공백으로 채우기
df['별점']=df['별점'].fillna('')
df['리뷰']=df['리뷰'].fillna('')
df['홈페이지']=df['홈페이지'].fillna('')

# %%
#index를 포함하지 않고 데이터 저장
df.to_csv("제주도 기념품샵 목록.csv", index=False)
