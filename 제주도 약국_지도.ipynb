# %%
import folium
import pandas as pd

# %%
df = pd.read_csv('./제주도 약국 목록.csv')      
df
# Out:
#         약국명         위도          경도                                 주소  \
# 0      새별약국  33.408671  126.264335  제주특별자치도 제주시 한림읍 동명북1길 11, 1층 102호
# 1     구름별약국  33.487931  126.502058      제주특별자치도 제주시 연오로 59, 지1층 101호
# 2     알로하약국  33.520836  126.859273            제주특별자치도 제주시 구좌읍 세화12길 1
# 3      삼양약국  33.520884  126.584080          제주특별자치도 제주시 일주동로 366, 1층
# 4    곰온누리약국  33.486418  126.414566    제주특별자치도 제주시 애월읍 하귀9길 2, 1층 106호
# ..      ...        ...         ...                                ...
# 304    최고약국  33.253106  126.559360            제주특별자치도 서귀포시 일주동로 8696
# 305   용머리약국  33.233815  126.310356      제주특별자치도 서귀포시 안덕면 사계남로216번길 29
# 306    감귤약국  33.249022  126.566882                제주특별자치도 서귀포시 동문로 64
# 307   모슬포약국  33.221000  126.250818        제주특별자치도 서귀포시 대정읍 신영로 75, 1층
# 308   금강한약국  33.256479  126.505300               제주특별자치도 서귀포시 신서로 69
#
#           주소2
# 0     한림읍 동명리
# 1        오라삼동
# 2     구좌읍 세화리
# 3        삼양이동
# 4    애월읍 하귀1리
# ..        ...
# 304       서홍동
# 305   안덕면 사계리
# 306       서귀동
# 307   대정읍 하모리
# 308       강정동
#
# [309 rows x 5 columns]

# %%
#folium.Map() 함수 사용하여 지도 객체 생성하기
#df의 위도와 경도 열의 평균값인 위치에 해당하는 지도를 생성하고 확대 수준을 10으로 설정
map=folium.Map(location=[df.위도.mean(), df.경도.mean()], zoom_start=10)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c25326bacdc9629b72e0b406a85ab28 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c25326bacdc9629b72e0b406a85ab28&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c25326bacdc9629b72e0b406a85ab28 = L.map(
#                 &quot;map_8c25326bacdc9629b72e0b406a85ab28&quot;,
#                 {
#                     center: [33.43789690008163, 126.51447049595686],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b0b5f512d7dbc14413979a76a4aea174 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_b0b5f512d7dbc14413979a76a4aea174.addTo(map_8c25326bacdc9629b72e0b406a85ab28);
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#제주시(blue)-서귀포시(green) 구분해서 folium.Marker
tiles = "http://mt0.google.com/vt/lyrs=m&hl=ko&x={x}&y={y}&z={z}" #구글지도 타일 설정
attr= "Google" #속성 설정
map = folium.Map(location=[df['위도'].mean(), df['경도'].mean()], #folium을 사용하여 지도 초기화
                 zoom_start=10, tiles=tiles, attr=attr)
for i in df.index: #df의 각 행을 반복
    if '제주시' in df.loc[i, '주소']:
        folium.Marker(
            location=[df.loc[i, '위도'], df.loc[i, '경도']],
            tooltip=df.loc[i, '약국명'], #마커에 마우스를 올렸을 때 표시되는 툴팁으로 약국명 표시
            popup=folium.Popup(df.loc[i, '주소'], max_width=200),
            icon=folium.Icon(color='green', icon='glyphicon-plus')
        ).add_to(map)
    else:
        folium.Marker(
            location=[df.loc[i, '위도'], df.loc[i, '경도']],
            tooltip=df.loc[i, '약국명'], #마커에 마우스를 올렸을 때 표시되는 툴팁으로 약국명 표시
            popup=folium.Popup(df.loc[i, '주소'], max_width=200),
            icon=folium.Icon(color='blue', icon='glyphicon-plus')
        ).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d7925882c68f388b42c39e35aa63c909 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d7925882c68f388b42c39e35aa63c909&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d7925882c68f388b42c39e35aa63c909 = L.map(
#                 &quot;map_d7925882c68f388b42c39e35aa63c909&quot;,
#                 {
#                     center: [33.43789690008163, 126.51447049595686],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8758a27e003d74c572bcd43e47db7893 = L.tileLayer(
#                 &quot;http://mt0.google.com/vt/lyrs=m\u0026hl=ko\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_8758a27e003d74c572bcd43e47db7893.addTo(map_d7925882c68f388b42c39e35aa63c909);
#
#             var marker_84d22447435bc9345108e44e4a8ba990 = L.marker(
#                 [33.4086706105879, 126.264335201423],
#                 {}
#             ).addTo(map_d7925882c68f388b42c39e35aa63c909);
#
#
#             var icon_1897e2fffe6acf64ff16237a5adc4445 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-plus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_84d22447435bc9345108e44e4a8ba990.setIcon(icon_1897e2fffe6acf64ff16237a5adc4445);
#
#
#         var popup_1022784552b81a55b2c32c22c53ccefc = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_92b1d38f3f4b9adbb0654f00c50772f8 = $(`&lt;div id=&quot;html_92b1d38f3f4b9adbb0654f00c50772f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주특별자치도 제주시 한림읍 동명북1길 11, 1층 102호&lt;/div&gt;`)[0];
#                 popup_1022784552b81a55b2c32c22c53ccefc.setContent(html_92b1d38f3f4b9adbb0654f00c50772f8);
#
#
#
#         marker_84d22447435bc9345108e44e4a8ba990.bindPopup(popup_1022784552b81a55b2c32c22c53ccefc)
#         ;
#
#
#
#
#             marker_84d22447435bc9345108e44e4a8ba990.bindTooltip(
#                 `&lt;div&gt;
#                      새별약국
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d491696b68fb29e0ceeae112569772d4 = L.marker(
#                 [33.4879308657759, 126.502057860304],
#                 {}
#             ).addTo(map_d7925882c68f388b42c39e35aa63c909);
#
#
#             var icon_8722669bb2dbce8b47c5376f9fcd181a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-plus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d491696b68fb29e0ceeae112569772d4.setIcon(icon_8722669bb2dbce8b47c5376f9fcd181a);
#
#
#         var popup_d63cf8ddc91d8471de1a3cfe4f84f2ab = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_9a4a6f8d3387485eaa41ac59cf7d3b3b = $(`&lt;div id=&quot;html_9a4a6f8d3387485eaa41ac59cf7d3b3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주특별자치도 제주시 연오로 59, 지1층 101호 &lt;/div&gt;`)[0];
#                 popup_d63cf8ddc91d8471de1a3cfe4f84f2ab.setContent(html_9a4a6f8d3387485eaa41ac59cf7d3b3b);
#
#
#
#         marker_d491696b68fb29e0ceeae112569772d4.bindPopup(popup_d63cf8ddc91d8471de1a3cfe4f84f2ab)
#         ;
#
#
#
#
#             marker_d491696b68fb29e0ceeae112569772d4.bindTooltip(
#                 `&lt;div&gt;
#                      구름별약국
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_512989ccf164b4e7756eab99c7ee8be0 = L.marker(
#                 [33.5208359636264, 126.85927280891],
#                 {}
#             ).addTo(map_d7925882c68f388b42c39e35aa63c909);
#
#
#             var icon_f23b5cefa73177e12c09a59799d7500f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-plus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_512989ccf164b4e7756eab99c7ee8be0.setIcon(icon_f23b5cefa73177e12c09a59799d7500f);
#
#
#         var popup_1049fe7cf776724a58f25cdd7c3309c1 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_fe1aaea8fd4bf6b0af9f1f5b4cdf5043 = $(`&lt;div id=&quot;html_fe1aaea8fd4bf6b0af9f1f5b4cdf5043&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주특별자치도 제주시 구좌읍 세화12길 1&lt;/div&gt;`)[0];
#                 popup_1049fe7cf776724a58f25cdd7c3309c1.setContent(html_fe1aaea8fd4bf6b0af9f1f5b4cdf5043);
#
#
#
#         marker_512989ccf164b4e7756eab99c7ee8be0.bindPopup(popup_1049fe7cf776724a58f25cdd7c3309c1)
#         ;
