# %%
import folium
import pandas as pd

# %%
df = pd.read_csv('./제주도 기념품샵 목록.csv')      
df
# Out:
#                        이름                              주소   별점  \
# 0                    바이제주          제주특별자치도 제주시 서해안로 626    5.0
# 1                    바이제주          제주특별자치도 제주시 서해안로 626    1.0
# 2                    바이제주          제주특별자치도 제주시 서해안로 626    4.0
# 3                    바이제주          제주특별자치도 제주시 서해안로 626    5.0
# 4                    바이제주          제주특별자치도 제주시 서해안로 626    4.0
# ...                   ...                             ...  ...
# 2070              한라산기프트몰          제주특별자치도 제주시 진동로1길 24    5.0
# 2071     Bakeshirts Store      제주특별자치도 제주시 조천읍 대흘2길 1 2층   5.0
# 2072                 귤아주망  제주특별자치도 서귀포시 대정읍 영서중로13번길 11    NaN
# 2073  공중전화 서귀포약천사 기념품판매점옆      제주특별자치도 서귀포시 이어도로 293-28    5.0
# 2074                 꿈팩토리        제주특별자치도 제주시 다랑곶2길 50 1층   NaN
#
#                                                      리뷰  \
# 0     매장도 깨끗하고 상품도 다양하네요. 열쇠고리나 일반 책갈피도 기본 만원 이상이라서 ...
# 1       핸드메이드 제품은 많음근데 과자 여기서 사지말고 시장가서 사시길저도 알고싶지않았음^^
# 2                                     재밌고 흥미로운 아이템  많던곳
# 3                                                   NaN
# 4                                               종류가 많음.
# ...                                                 ...
# 2070  문의 드리고 할 때마다 이것저것 꼼꼼하게 잘 알려주시고, 가겨도 다른 곳이랑 비교해...
# 2071                                           느낌이가 조아요
# 2072                                                NaN
# 2073                  생각지 않게 수월관음도 감상 할 수 있어  무척 좋았습니다.
# 2074                                                NaN
#
#                                 홈페이지         위도          경도      주소2
# 0           blog.naver.com/byjeju365  33.516543  126.504111     용담삼동
# 1           blog.naver.com/byjeju365  33.516543  126.504111     용담삼동
# 2           blog.naver.com/byjeju365  33.516543  126.504111     용담삼동
# 3           blog.naver.com/byjeju365  33.516543  126.504111     용담삼동
# 4           blog.naver.com/byjeju365  33.516543  126.504111     용담삼동
# ...                              ...        ...         ...      ...
# 2070                  jejuhongbo.com  33.519222  126.566790     화북일동
# 2071  instagram.com/bakeshirts_store  33.498281  126.654652  조천읍 대흘리
# 2072                             NaN  33.222039  126.254676  대정읍 하모리
# 2073                             NaN  33.245278  126.450182      대포동
# 2074      www.instagram.com/ggumaker  33.490599  126.475935      노형동
#
# [2075 rows x 8 columns]

# %%
#folium.Map() 함수 사용하여 지도 객체 생성하기
#df의 위도와 경도 열의 평균값인 위치에 해당하는 지도를 생성하고 확대 수준을 10으로 설정
map=folium.Map(location=[df.위도.mean(), df.경도.mean()], zoom_start=10)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58df1cfa056dadcd821bbe394beb84f3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58df1cfa056dadcd821bbe394beb84f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58df1cfa056dadcd821bbe394beb84f3 = L.map(
#                 &quot;map_58df1cfa056dadcd821bbe394beb84f3&quot;,
#                 {
#                     center: [33.442351450328616, 126.57429582464898],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af8e24b11e2361b0e1b3d7a981210026 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_af8e24b11e2361b0e1b3d7a981210026.addTo(map_58df1cfa056dadcd821bbe394beb84f3);
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#제주시(blue)-서귀포시(green) 구분해서 folium.Marker
tiles = "http://mt0.google.com/vt/lyrs=m&hl=ko&x={x}&y={y}&z={z}" #구글지도 타일 설정
attr= "Google" #속성 설정
map = folium.Map(location=[df['위도'].mean(), df['경도'].mean()], #folium을 사용하여 지도 초기화
                 zoom_start=10, tiles=tiles, attr=attr)
for i in df.index: #df의 각 행을 반복
    if '제주시' in df.loc[i, '주소']:
        folium.Marker(
            location=[df.loc[i, '위도'], df.loc[i, '경도']],
            tooltip=df.loc[i, '이름'], #마커에 마우스를 올렸을 때 표시되는 툴팁으로 이름 표시
            popup=folium.Popup(df.loc[i, '주소'], max_width=200),
            icon=folium.Icon(color='green', icon='glyphicon-gift')
        ).add_to(map)
    else:
        folium.Marker(
            location=[df.loc[i, '위도'], df.loc[i, '경도']],
            tooltip=df.loc[i, '이름'], #마커에 마우스를 올렸을 때 표시되는 툴팁으로 이름 표시
            popup=folium.Popup(df.loc[i, '주소'], max_width=200),
            icon=folium.Icon(color='blue', icon='glyphicon-gift')
        ).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2826aa8ff461db0fb0112101863d8c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2826aa8ff461db0fb0112101863d8c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2826aa8ff461db0fb0112101863d8c9 = L.map(
#                 &quot;map_a2826aa8ff461db0fb0112101863d8c9&quot;,
#                 {
#                     center: [33.442351450328616, 126.57429582464898],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14a832e231d7a10ed5d7fc5b3ac18b87 = L.tileLayer(
#                 &quot;http://mt0.google.com/vt/lyrs=m\u0026hl=ko\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_14a832e231d7a10ed5d7fc5b3ac18b87.addTo(map_a2826aa8ff461db0fb0112101863d8c9);
#
#             var marker_38aed49753216ae0fa86ee3fbb76e590 = L.marker(
#                 [33.5165428769717, 126.504110857612],
#                 {}
#             ).addTo(map_a2826aa8ff461db0fb0112101863d8c9);
#
#
#             var icon_18ebfa72974413ef757b848ba8ca2832 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-gift&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_38aed49753216ae0fa86ee3fbb76e590.setIcon(icon_18ebfa72974413ef757b848ba8ca2832);
#
#
#         var popup_d0fe53af596cae8ebb7ecf736734dbf9 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_0bfedf9dc442b210ecae17e4d69fddf7 = $(`&lt;div id=&quot;html_0bfedf9dc442b210ecae17e4d69fddf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주특별자치도 제주시 서해안로 626  &lt;/div&gt;`)[0];
#                 popup_d0fe53af596cae8ebb7ecf736734dbf9.setContent(html_0bfedf9dc442b210ecae17e4d69fddf7);
#
#
#
#         marker_38aed49753216ae0fa86ee3fbb76e590.bindPopup(popup_d0fe53af596cae8ebb7ecf736734dbf9)
#         ;
#
#
#
#
#             marker_38aed49753216ae0fa86ee3fbb76e590.bindTooltip(
#                 `&lt;div&gt;
#                      바이제주
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4d58ab86fa7d3be4a7c2fea811a07b24 = L.marker(
#                 [33.5165428769717, 126.504110857612],
#                 {}
#             ).addTo(map_a2826aa8ff461db0fb0112101863d8c9);
#
#
#             var icon_19218b3eec5d135466562ce43dc52b84 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-gift&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4d58ab86fa7d3be4a7c2fea811a07b24.setIcon(icon_19218b3eec5d135466562ce43dc52b84);
#
#
#         var popup_bda92ac81758d300743d783eafad1833 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_34566009228e1c177011b58827715cb9 = $(`&lt;div id=&quot;html_34566009228e1c177011b58827715cb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주특별자치도 제주시 서해안로 626  &lt;/div&gt;`)[0];
#                 popup_bda92ac81758d300743d783eafad1833.setContent(html_34566009228e1c177011b58827715cb9);
#
#
#
#         marker_4d58ab86fa7d3be4a7c2fea811a07b24.bindPopup(popup_bda92ac81758d300743d783eafad1833)
#         ;
#
#
#
#
#             marker_4d58ab86fa7d3be4a7c2fea811a07b24.bindTooltip(
#                 `&lt;div&gt;
#                      바이제주
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1db37f3f629b23f14e24a33ee30fcfa7 = L.marker(
#                 [33.5165428769717, 126.504110857612],
#                 {}
#             ).addTo(map_a2826aa8ff461db0fb0112101863d8c9);
#
#
#             var icon_68736fe1585f9fa052e39e9ace7b785b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-gift&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1db37f3f629b23f14e24a33ee30fcfa7.setIcon(icon_68736fe1585f9fa052e39e9ace7b785b);
#
#
#         var popup_14b6d9694adbbba5836636b596b7af2b = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_5a2ca69b194d369e3fca4f6d2d7a8a16 = $(`&lt;div id=&quot;html_5a2ca69b194d369e3fca4f6d2d7a8a16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주특별자치도 제주시 서해안로 626  &lt;/div&gt;`)[0];
#                 popup_14b6d9694adbbba5836636b596b7af2b.setContent(html_5a2ca69b194d369e3fca4f6d2d7a8a16);
#
#
#
#         marker_1db37f3f629b23f14e24a33ee30fcfa7.bindPopup(popup_14b6d9694adbbba5836636b596b7af2b)
#         ;
#
#
#
#
#             marker_1d
