# %%
import folium
import pandas as pd

# %%
df = pd.read_csv('./제주도 병원 목록.csv')      
df
# Out:
#              병원명   구분  토요일  일요일  공휴일                         주소         위도  \
# 0       중문삼성연합의원   의원    1    0    0         제주특별자치도 서귀포시 중문로 7  33.252693
# 1      조재익신경외과의원   의원    1    0    0  제주특별자치도 서귀포시 대정읍 하모중앙로 76  33.221390
# 2       제주현대안과의원   의원    0    1    0         제주특별자치도 제주시 건주로 31  33.516779
# 3          제주필의원   의원    1    0    1      제주특별자치도 제주시 일주동로 229   33.519443
# 4    제주연합재활의학과의원   의원    1    0    0        제주특별자치도 제주시 서광로 294  33.500204
# ..           ...  ...  ...  ...  ...                        ...        ...
# 492       바로내과의원   의원    1    0    0        제주특별자치도 서귀포시 월드컵로 8  33.248994
# 493    이승희산부인과의원   의원    1    0    0     제주특별자치도 제주시 서광로 208-1   33.499628
# 494       제주내과의원   의원    1    0    0      제주특별자치도 제주시 서광로 78-9   33.499522
# 495   김동호이비인후과의원   의원    1    0    0       제주특별자치도 제주시 서광로 267   33.500235
# 496     강주현피부과의원   의원    1    0    0         제주특별자치도 제주시 건주로 27  33.517088
#
#              경도      주소2
# 0    126.423028      중문동
# 1    126.251812  대정읍 하모리
# 2    126.580983     도련일동
# 3    126.569948     화북일동
# 4    126.527884     이도이동
# ..          ...      ...
# 492  126.507323      강정동
# 493  126.518719     삼도일동
# 494  126.505258     오라삼동
# 495  126.524945     삼도일동
# 496  126.581141     도련일동
#
# [497 rows x 9 columns]

# %%
#folium.Map() 함수 사용하여 지도 객체 생성하기
#df의 위도와 경도 열의 평균값인 위치에 해당하는 지도를 생성하고 확대 수준을 10으로 설정
map=folium.Map(location=[df.위도.mean(), df.경도.mean()], zoom_start=10)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04f2df973b01915b0b2b77b6634cce19 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04f2df973b01915b0b2b77b6634cce19&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04f2df973b01915b0b2b77b6634cce19 = L.map(
#                 &quot;map_04f2df973b01915b0b2b77b6634cce19&quot;,
#                 {
#                     center: [33.4354726792669, 126.51468610177211],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_489074147700fe0b3a4ad626bf76ef67 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_489074147700fe0b3a4ad626bf76ef67.addTo(map_04f2df973b01915b0b2b77b6634cce19);
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#제주시(blue)-서귀포시(green) 구분해서 folium.Marker
tiles = "http://mt0.google.com/vt/lyrs=m&hl=ko&x={x}&y={y}&z={z}" #구글지도 타일 설정
attr= "Google" #속성 설정
map = folium.Map(location=[df['위도'].mean(), df['경도'].mean()], #folium을 사용하여 지도 초기화
                 zoom_start=10, tiles=tiles, attr=attr)
for i in df.index: #df의 각 행을 반복
    if '제주시' in df.loc[i, '주소']:
        folium.Marker(
            location=[df.loc[i, '위도'], df.loc[i, '경도']],
            tooltip=df.loc[i, '병원명'], #마커에 마우스를 올렸을 때 표시되는 툴팁으로 병원명 표시
            popup=folium.Popup(df.loc[i, '주소'], max_width=200),
            icon=folium.Icon(color='green', icon='glyphicon-heart-empty')
        ).add_to(map)
    else:
        folium.Marker(
            location=[df.loc[i, '위도'], df.loc[i, '경도']],
            tooltip=df.loc[i, '병원명'], #마커에 마우스를 올렸을 때 표시되는 툴팁으로 병원명 표시
            popup=folium.Popup(df.loc[i, '주소'], max_width=200),
            icon=folium.Icon(color='blue', icon='glyphicon-heart-empty')
        ).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4cc8ba52661d3f86a9d57d0e94769ad2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4cc8ba52661d3f86a9d57d0e94769ad2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4cc8ba52661d3f86a9d57d0e94769ad2 = L.map(
#                 &quot;map_4cc8ba52661d3f86a9d57d0e94769ad2&quot;,
#                 {
#                     center: [33.4354726792669, 126.51468610177211],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4967983f0853c90232be6d91026b6853 = L.tileLayer(
#                 &quot;http://mt0.google.com/vt/lyrs=m\u0026hl=ko\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_4967983f0853c90232be6d91026b6853.addTo(map_4cc8ba52661d3f86a9d57d0e94769ad2);
#
#             var marker_4e63f7737a063af82b24ccf03a5d616d = L.marker(
#                 [33.2526933883842, 126.423027950794],
#                 {}
#             ).addTo(map_4cc8ba52661d3f86a9d57d0e94769ad2);
#
#
#             var icon_09417e89572ab2788d411bd03b6b1ed0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-heart-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4e63f7737a063af82b24ccf03a5d616d.setIcon(icon_09417e89572ab2788d411bd03b6b1ed0);
#
#
#         var popup_749f1cb222c065edb5c63371f30c5c84 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_d224ee4ccd6e47489af65822ad92b562 = $(`&lt;div id=&quot;html_d224ee4ccd6e47489af65822ad92b562&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주특별자치도 서귀포시 중문로 7&lt;/div&gt;`)[0];
#                 popup_749f1cb222c065edb5c63371f30c5c84.setContent(html_d224ee4ccd6e47489af65822ad92b562);
#
#
#
#         marker_4e63f7737a063af82b24ccf03a5d616d.bindPopup(popup_749f1cb222c065edb5c63371f30c5c84)
#         ;
#
#
#
#
#             marker_4e63f7737a063af82b24ccf03a5d616d.bindTooltip(
#                 `&lt;div&gt;
#                      중문삼성연합의원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2fe6d540902e2034182c78e009922bec = L.marker(
#                 [33.2213903495082, 126.251812065618],
#                 {}
#             ).addTo(map_4cc8ba52661d3f86a9d57d0e94769ad2);
#
#
#             var icon_8fd973627f1841343fb776ff212de013 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-heart-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2fe6d540902e2034182c78e009922bec.setIcon(icon_8fd973627f1841343fb776ff212de013);
#
#
#         var popup_0d83e8d1f53130cd2c583b635b437f2c = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_cb3bed43fa3a7f717d0a7d410165ecf3 = $(`&lt;div id=&quot;html_cb3bed43fa3a7f717d0a7d410165ecf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주특별자치도 서귀포시 대정읍 하모중앙로 76&lt;/div&gt;`)[0];
#                 popup_0d83e8d1f53130cd2c583b635b437f2c.setContent(html_cb3bed43fa3a7f717d0a7d410165ecf3);
#
#
#
#         marker_2fe6d540902e2034182c78e009922bec.bindPopup(popup_0d83e8d1f53130cd2c583b635b437f2c)
#         ;
#
#
#
#
#             marker_2fe6d540902e2034182c78e009922bec.bindTooltip(
#                 `&lt;div&gt;
#                      조재익신경외과의원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4f2160b5956ce6fbf4cdcb1cc505c59d = L.marker(
#                 [33.5167785217559, 126.580982878284],
#                 {}
#             ).addTo(map_4cc8ba52661d3f86a9d57d0e94769ad2);
#
#
#             var icon_b1b75c51c89713ecffddd617c5dd48a4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-heart-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4f2160b5956ce6fbf4cdcb1cc505c59d.setIcon(icon_b1b75c51c89713ecffddd617c5dd48a4);
#
#
#         var popup_625b69d2289847752287c796403c0830 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_f502da700ad3eaef5de5386c9d043197 = $(`&lt;div id=&quot;html_f502da700ad3eaef5de5386c9d043197&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주특별자치도 제주시 건주로 31&lt;/div&gt;`)[0];
#                 popup_625b69d2289847752287c796403c0830.setContent(html_f502da700ad3eaef5de5386c9d043197);
#
#
#
#         marker_4f2160b5956ce6fbf4cdcb1cc505c59d.bindPopup(popup_625b69d2289847752287c796403c0830)
#         ;
