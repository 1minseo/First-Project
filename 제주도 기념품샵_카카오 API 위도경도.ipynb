# %%
import requests, json
import pandas as pd
from urllib.parse import quote

# %%
#API 키 가져오기
with open('C:/workspace/kakao.txt') as file:
    road_key = file.read()

# URL 만들기
base_url = 'https://dapi.kakao.com/v2/local/search/address.json'
addr = '제주특별자치도 제주시 서해안로 626'
url = f'{base_url}?query={quote(addr)}'

#Header : Authorization: KakaoAK ${REST_API_KEY}
header = {'Authorization': f'KakaoAK {road_key}'}

#Kakao Local API 호출하여 결과 가져오기
result = requests.get(url, headers=header).json()
result
# Out:
# {'documents': [{'address': {'address_name': '제주특별자치도 제주시 용담삼동 1023-2',
#     'b_code': '5011011000',
#     'h_code': '5011058000',
#     'main_address_no': '1023',
#     'mountain_yn': 'N',
#     'region_1depth_name': '제주특별자치도',
#     'region_2depth_name': '제주시',
#     'region_3depth_h_name': '용담2동',
#     'region_3depth_name': '용담삼동',
#     'sub_address_no': '2',
#     'x': '126.504110857612',
#     'y': '33.5165428769717'},
#    'address_name': '제주특별자치도 제주시 서해안로 626',
#    'address_type': 'ROAD_ADDR',
#    'road_address': {'address_name': '제주특별자치도 제주시 서해안로 626',
#     'building_name': '',
#     'main_building_no': '626',
#     'region_1depth_name': '제주특별자치도',
#     'region_2depth_name': '제주시',
#     'region_3depth_name': '용담삼동',
#     'road_name': '서해안로',
#     'sub_building_no': '',
#     'underground_yn': 'N',
#     'x': '126.504110857612',
#     'y': '33.5165428769717',
#     'zone_no': '63150'},
#    'x': '126.504110857612',
#    'y': '33.5165428769717'}],
#  'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}

# %%
lat = result['documents'][0]['y'] #위도(latitude)
lng = result['documents'][0]['x'] #경도(latitude)
dong=result['documents'][0]['address']['region_3depth_name']

lat, lng, dong
# Out:
# ('33.5165428769717', '126.504110857612', '용담삼동')

# %%
#제주도 기념품샵 정보 완성하기
df = pd.read_csv("C:/workspace/프로젝트/최종/제주도 기념품샵 목록.csv")
df
# Out:
#                        이름                              주소   별점  \
# 0                    바이제주          제주특별자치도 제주시 서해안로 626    5.0
# 1                    바이제주          제주특별자치도 제주시 서해안로 626    1.0
# 2                    바이제주          제주특별자치도 제주시 서해안로 626    4.0
# 3                    바이제주          제주특별자치도 제주시 서해안로 626    5.0
# 4                    바이제주          제주특별자치도 제주시 서해안로 626    4.0
# ...                   ...                             ...  ...
# 2242              한라산기프트몰          제주특별자치도 제주시 진동로1길 24    5.0
# 2243     Bakeshirts Store      제주특별자치도 제주시 조천읍 대흘2길 1 2층   5.0
# 2244                 귤아주망  제주특별자치도 서귀포시 대정읍 영서중로13번길 11    NaN
# 2245  공중전화 서귀포약천사 기념품판매점옆      제주특별자치도 서귀포시 이어도로 293-28    5.0
# 2246                 꿈팩토리        제주특별자치도 제주시 다랑곶2길 50 1층   NaN
#
#                                                      리뷰  \
# 0     매장도 깨끗하고 상품도 다양하네요. 열쇠고리나 일반 책갈피도 기본 만원 이상이라서 ...
# 1       핸드메이드 제품은 많음근데 과자 여기서 사지말고 시장가서 사시길저도 알고싶지않았음^^
# 2                                     재밌고 흥미로운 아이템  많던곳
# 3                                                   NaN
# 4                                               종류가 많음.
# ...                                                 ...
# 2242  문의 드리고 할 때마다 이것저것 꼼꼼하게 잘 알려주시고, 가겨도 다른 곳이랑 비교해...
# 2243                                           느낌이가 조아요
# 2244                                                NaN
# 2245                  생각지 않게 수월관음도 감상 할 수 있어  무척 좋았습니다.
# 2246                                                NaN
#
#                                 홈페이지
# 0           blog.naver.com/byjeju365
# 1           blog.naver.com/byjeju365
# 2           blog.naver.com/byjeju365
# 3           blog.naver.com/byjeju365
# 4           blog.naver.com/byjeju365
# ...                              ...
# 2242                  jejuhongbo.com
# 2243  instagram.com/bakeshirts_store
# 2244                             NaN
# 2245                             NaN
# 2246      www.instagram.com/ggumaker
#
# [2247 rows x 5 columns]

# %%
lat_list, lng_list, dong_list = [], [], [] #빈 리스트 생성. 위도와 경도 값 저장
for i in df.index: #df의 각 행에 대해 반복
    url = f'{base_url}?query={quote(df["주소"][i])}'
    result = requests.get(url, headers=header).json() #API에 요청을 보내고 응답을 JSON 형식으로 받음
    try:
        lat_list.append(result['documents'][0]['y']) #위도(y) 추출하여 lat_list에 추가
        lng_list.append(result['documents'][0]['x']) #경도(x) 추출하여 lng_list에 추가
        dong_list.append(result['documents'][0]['address']['region_3depth_name'])
    except:
        print(df.이름[i])  
#try-except 구문: try블록 실행 중 예외 발생 시 except블록 실행
# Out:
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 도두몰
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 제주고래감성소품
# 제주고래감성소품
# 제라몽

# %%
df[df['이름']=='선물고팡 제주공항점']
# Out:
#              이름                        주소   별점  \
# 203  선물고팡 제주공항점  제주특별자치도 제주시 월성로 15 1,2층   4.0
# 204  선물고팡 제주공항점  제주특별자치도 제주시 월성로 15 1,2층   5.0
# 205  선물고팡 제주공항점  제주특별자치도 제주시 월성로 15 1,2층   5.0
# 206  선물고팡 제주공항점  제주특별자치도 제주시 월성로 15 1,2층   5.0
# 207  선물고팡 제주공항점  제주특별자치도 제주시 월성로 15 1,2층   5.0
# ..          ...                       ...  ...
# 317  선물고팡 제주공항점  제주특별자치도 제주시 월성로 15 1,2층   5.0
# 318  선물고팡 제주공항점  제주특별자치도 제주시 월성로 15 1,2층   5.0
# 319  선물고팡 제주공항점  제주특별자치도 제주시 월성로 15 1,2층   5.0
# 320  선물고팡 제주공항점  제주특별자치도 제주시 월성로 15 1,2층   5.0
# 321  선물고팡 제주공항점  제주특별자치도 제주시 월성로 15 1,2층   5.0
#
#                                                     리뷰  \
# 203  다른데 돌아다니면서 본 것들이 대부분이고 다른데에는 있는 없는게 많아서 종류사 많이...
# 204  아기자기한 소품들부터 제주특산물 진짜 많네요 구경하는 재미도 쏠쏠해요 귤한박스랑 제...
# 205  특색 있는 제품이 많아서 기념품 선물로 좋네요 제주상징인 선물로 구매했는데 지인들이...
# 206  제주 마지막날 기념품 사러 들렸어요 감귤과자 구매했는데 선물용으로 깔끔하고 좋은듯요...
# 207  감성소품 수사물 특산물 청과물까지 다양했어요 2층까지 있어서 규모도 크네요 선물용으...
# ..                                                 ...
# 317  가족여행 와서 마지막에 기분좋게 쇼핑하고 가요~픽업 친절하시고 옥상정원은 최고네여~...
# 318  아기자기한 소품들도 많고 가격대비 짱이에요! 무엇보다 옥상정원에서 보이는 공항활주로...
# 319     저령한가격과 특산품과 감성소품을동시에구매가능한 제주도 유일한 매장이네요최고에요~^^
# 320                              가격도 저렴하고 제품도 좋습니다. ^^
# 321                                                NaN
#
#                              홈페이지
# 203  www.instagram.com/giftgopang
# 204  www.instagram.com/giftgopang
# 205  www.instagram.com/giftgopang
# 206  www.instagram.com/giftgopang
# 207  www.instagram.com/giftgopang
# ..                            ...
# 317  www.instagram.com/giftgopang
# 318  www.instagram.com/giftgopang
# 319  www.instagram.com/giftgopang
# 320  www.instagram.com/giftgopang
# 321  www.instagram.com/giftgopang
#
# [119 rows x 5 columns]

# %%
#map함수를 활용해 선물고팡 제주공항점 주소 변경
df.loc[203:321, '주소'] = df.loc[203:321]['주소'].map({'제주특별자치도 제주시 월성로 15 1,2층 ':'제주특별자치도 제주시 월성로 15 1'})

# %%
df.head()
# Out:
#      이름                      주소   별점  \
# 0  바이제주  제주특별자치도 제주시 서해안로 626    5.0
# 1  바이제주  제주특별자치도 제주시 서해안로 626    1.0
# 2  바이제주  제주특별자치도 제주시 서해안로 626    4.0
# 3  바이제주  제주특별자치도 제주시 서해안로 626    5.0
# 4  바이제주  제주특별자치도 제주시 서해안로 626    4.0
#
#                                                   리뷰                      홈페이지
# 0  매장도 깨끗하고 상품도 다양하네요. 열쇠고리나 일반 책갈피도 기본 만원 이상이라서 ...  blog.naver.com/byjeju365
# 1    핸드메이드 제품은 많음근데 과자 여기서 사지말고 시장가서 사시길저도 알고싶지않았음^^  blog.naver.com/byjeju365
# 2                                  재밌고 흥미로운 아이템  많던곳  blog.naver.com/byjeju365
# 3                                                NaN  blog.naver.com/byjeju365
# 4                                            종류가 많음.  blog.naver.com/byjeju365

# %%
df[df['이름']=='더아일랜더']
# Out:
#          이름                         주소   별점  \
# 1172  더아일랜더  제주특별자치도 제주시 관덕로4길 7 1,2층   5.0
# 1173  더아일랜더  제주특별자치도 제주시 관덕로4길 7 1,2층   5.0
# 1174  더아일랜더  제주특별자치도 제주시 관덕로4길 7 1,2층   5.0
# 1175  더아일랜더  제주특별자치도 제주시 관덕로4길 7 1,2층   5.0
# 1176  더아일랜더  제주특별자치도 제주시 관덕로4길 7 1,2층   5.0
# 1177  더아일랜더  제주특별자치도 제주시 관덕로4길 7 1,2층   5.0
# 1178  더아일랜더  제주특별자치도 제주시 관덕로4길 7 1,2층   5.0
# 1196                  제시카님의 제주사진컬렉션 color of jeju 좋아요~!  the-islander.co.kr
# 1197                                         통장 다 털렸어요.  the-islander.co.kr
# 1198                                                NaN  the-islander.co.kr
# 1199  구경 했는데.. 뭐가 특별한지 잘 모르겠어요. 다르다고해서 일부러 갔는데ㅡㅡ 기념품...  the-islander.co.kr
# 1200                   패키지가 너무 예뻐요!!!!! 다른 소품샵과는 다른 느낌!  the-islander.co.kr
# 1201  안 갔으면 후회할뻔 앞으로 제주도 들릴때마다 올 듯위치도 좋고 상품도 갬성터짐 더아...  the-islander.co.kr
# 1202  제주여행 마지막에 렌트카 반납 전 항상 들르는 곳. 지인들 선물 사기도 너무 좋고 ...  the-islander.co.kr
# 1203  정말 위험해요,,아래 리뷰 보고 설마 했는데 쓸어 담다보니 텅장이 되었어요선물 용도...  the-islander.co.kr
# 1204                가본 소품샵 중 최고, 이리저리 다녀봤지만 여기만한곳이 없네요.  the-islander.co.kr
# 1205                            정말 위험합니다 통장 다 털릴 뻔 했습니다  the-islander.co.kr
# 1206  음.. 깔끔하구 카페랑 같이되있어서 괜춘괜춘 구매하면 커피 할인권 줌 쫌 가격대 나...  the-islander.co.kr
# 1207                     특이하고 아기자기한 소품 많아서 좋았어요!!!! : )  the-islander.co.kr
# 1208  흔한 기념품은 아니지만좀 실용적이고 아기자기한 제주 기념품 구매하고 싶다면 방문하기...  the-islander.co.kr
# 1209  제주스러운 예쁘고 독특한 기념품도 많지만 독특한 소품이 많아서 종종 들리는 기념품 ...  the-islander.co.kr
# 1210                                                NaN  the-islander.co.kr
# 1211  좀 가격은 있지만 아기자기하고 예쁜거 많아서 구경하는 재미가 쏠쏠했어용!!ㅎㅎㅎㅎ기...  the-islander.co.kr
# 1212                  다른곳과 겹치지않는 예쁜 기념품이 많고 분위기가 너무 좋아요  the-islander.co.kr
# 1213  근처 소품샵 다 들리고 여기 마지막으로 가보자 했는데 가격이 좀 있어도 이런곳에서 ...  the-islander.co.kr
# 1214                     밑 후기 동감ㅋㅋㅋ 막 사고 싶은 건 없는데 다 귀여움  the-islander.co.kr
# 1215              귀여운거 많다. 막 엄청 사고싶어지는 건 없지만 구경하는거 재밌다.  the-islander.co.kr
# 1216  내비로 찍고 가니 위치가 약간 달라요. (카카오 위치가 맞네요)지나가다 동문시장과 ...  the-islander.co.kr
# 1217  기념품샵 중에서는 확실히 차별화된 물품을 많이 팔고있고 그만큼 세련된 디자인도 많습...  the-islander.co.kr
# 1218                                      편집샵중에선 섬에서 최고  the-islander.co.kr
# 1219                                                NaN  the-islander.co.kr
# 1220                                   특별한 제주기념품 & 아트상품  the-islander.co.kr

# %%
#더아일랜더 주소 변경
df.loc[1172:1220, '주소'] = df.loc[1172:1220]['주소'].map({'제주특별자치도 제주시 관덕로4길 7 1,2층 ':'제주특별자치도 제주시 관덕로4길 7 1'})

# %%
df[df['이름']=='제주고래감성소품']
# Out:
#             이름                               주소   별점  \
# 1655  제주고래감성소품  제주특별자치도 제주시 애월읍 애월해안로 390 1,2층   5.0
# 1656  제주고래감성소품  제주특별자치도 제주시 애월읍 애월해안로 390 1,2층   5.0
#
#                                                      리뷰  \
# 1655  지나가다가 들어가 본 곳인데 너무너무 좋았어요 !! 예쁘기도 너무 예쁘고 가격대도 ...
# 1656  특색있고 아기자기한 예쁜 소품이 많아요.다른 소품샵에 없는 제품들이 많아서 좋았어요...
#
#                                  홈페이지
# 1655  www.instagram.com/jejuwhaleshop
# 1656  www.instagram.com/jejuwhaleshop

# %%
#제주고래감성소품 주소 변경
df.loc[1655:1656, '주소'] = df.loc[1655:1656]['주소'].map({'제주특별자치도 제주시 애월읍 애월해안로 390 1,2층 ':'제주특별자치도 제주시 애월읍 애월해안로 390 1'})

# %%
#수정된 데이터로 다시 위도경도 받아오기
lat_list, lng_list, dong_list = [], [], [] #빈 리스트 생성. 위도와 경도 값 저장
for i in df.index: #df의 각 행에 대해 반복
    url = f'{base_url}?query={quote(df["주소"][i])}'
    result = requests.get(url, headers=header).json() #API에 요청을 보내고 응답을 JSON 형식으로 받음
    try:
        lat_list.append(result['documents'][0]['y']) #위도(y) 추출하여 lat_list에 추가
        lng_list.append(result['documents'][0]['x']) #경도(x) 추출하여 lng_list에 추가
        dong_list.append(result['documents'][0]['address']['region_3depth_name'])
    except:
        print(df.이름[i])
#try-except 구문: try블록 실행 중 예외 발생 시 except블록 실행
# Out:
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 선물고팡 제주공항점
# 도두몰
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 더아일랜더
# 제주고래감성소품
# 제주고래감성소품
# 제라몽

# %%
#'선물고팡 제주공항점', '두몰', '더아일랜더', '제주고래감성소품', '제라몽' 행 제거
df=df[df.이름 != '선물고팡 제주공항점']
df=df[df.이름 != '도두몰']
df=df[df.이름 != '더아일랜더']
df=df[df.이름 != '제주고래감성소품']
df=df[df.이름 != '제라몽']

# %%
df['위도']=lat_list
df['경도']=lng_list
df['주소2']=dong_list

#제주도 기념품샵 위도 경도 동 리스트
lat_list
lng_list
dong_list
# Out:
# ['용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '용담삼동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '법환동',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '구좌읍 세화리',
#  '애월읍 봉성리',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '색달동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '조천읍 함덕리',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '연동',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '성산읍 성산리',
#  '안덕면 서광리',
#  '안덕면 서광리',
#  '안덕면 서광리',
#  '안덕면 서광리',
#  '안덕면 서광리',
#  '안덕면 서광리',
#  '안덕면 서광리',
#  '안덕면 서광리',
#  '안덕면 서광리',
#  '안덕면 서광리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '조천읍 선흘리',
#  '일도일동',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '애월읍 애월리',
#  '도두일동',
#  '도두일동',
#  '도두일동',
#  '용담일동',
#  '용담일동',
#  '용담일동',
#  '용담일동',
#  '용담일동',
#  '용담일동',
#  '용담일동',
#  '용담일동',
#  '용담일동',
#  '용담일동',
#  '용담일동',
#  '용담일동',
#  '이호일동',
#  '이호일동',
#  ...]

# %%
df.to_csv("제주도 기념품샵 목록.csv", index=False)

# %%
pd.read_csv('./제주도 기념품샵 목록.csv')
# Out:
#                        이름                              주소   별점  \
# 0                    바이제주          제주특별자치도 제주시 서해안로 626    5.0
# 1                    바이제주          제주특별자치도 제주시 서해안로 626    1.0
# 2                    바이제주          제주특별자치도 제주시 서해안로 626    4.0
# 3                    바이제주          제주특별자치도 제주시 서해안로 626    5.0
# 4                    바이제주          제주특별자치도 제주시 서해안로 626    4.0
# ...                   ...                             ...  ...
# 2070              한라산기프트몰          제주특별자치도 제주시 진동로1길 24    5.0
# 2071     Bakeshirts Store      제주특별자치도 제주시 조천읍 대흘2길 1 2층   5.0
# 2072                 귤아주망  제주특별자치도 서귀포시 대정읍 영서중로13번길 11    NaN
# 2073  공중전화 서귀포약천사 기념품판매점옆      제주특별자치도 서귀포시 이어도로 293-28    5.0
# 2074                 꿈팩토리        제주특별자치도 제주시 다랑곶2길 50 1층   NaN
#
#                                                      리뷰  \
# 0     매장도 깨끗하고 상품도 다양하네요. 열쇠고리나 일반 책갈피도 기본 만원 이상이라서 ...
# 1       핸드메이드 제품은 많음근데 과자 여기서 사지말고 시장가서 사시길저도 알고싶지않았음^^
# 2                                     재밌고 흥미로운 아이템  많던곳
# 3                                                   NaN
# 4                                               종류가 많음.
# ...                                                 ...
# 2070  문의 드리고 할 때마다 이것저것 꼼꼼하게 잘 알려주시고, 가겨도 다른 곳이랑 비교해...
# 2071                                           느낌이가 조아요
# 2072                                                NaN
# 2073                  생각지 않게 수월관음도 감상 할 수 있어  무척 좋았습니다.
# 2074                                                NaN
#
#                                 홈페이지         위도          경도      주소2
# 0           blog.naver.com/byjeju365  33.516543  126.504111     용담삼동
# 1           blog.naver.com/byjeju365  33.516543  126.504111     용담삼동
# 2           blog.naver.com/byjeju365  33.516543  126.504111     용담삼동
# 3           blog.naver.com/byjeju365  33.516543  126.504111     용담삼동
# 4           blog.naver.com/byjeju365  33.516543  126.504111     용담삼동
# ...                              ...        ...         ...      ...
# 2070                  jejuhongbo.com  33.519222  126.566790     화북일동
# 2071  instagram.com/bakeshirts_store  33.498281  126.654652  조천읍 대흘리
# 2072                             NaN  33.222039  126.254676  대정읍 하모리
# 2073                             NaN  33.245278  126.450182      대포동
# 2074      www.instagram.com/ggumaker  33.490599  126.475935      노형동
#
# [2075 rows x 8 columns]
