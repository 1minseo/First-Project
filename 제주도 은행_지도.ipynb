# %%
import folium
import pandas as pd

# %%
df = pd.read_csv('./제주도 은행 목록.csv')      
df
# Out:
#                      은행명                                 주소         위도  \
# 0        KB국민은행 제주종합금융센터   제주특별자치도 제주시 남광북1길 1 제주법조타워 1,2층   33.494593
# 1           KB국민은행 연북로지점                제주특별자치도 제주시 연북로 50   33.481592
# 2            하나은행 제주금융센터                제주특별자치도 제주시 중앙로 58   33.512922
# 3              신한은행 제주지점               제주특별자치도 제주시 중앙로 166   33.504033
# 4             하나은행 신제주지점         제주특별자치도 제주시 1100로 3308 1층   33.481632
# ..                   ...                                ...        ...
# 157       태흥새마을금고 제1분사무소          제주특별자치도 서귀포시 남원읍 태위로 810   33.282822
# 158    스마트저축은행 제주여신전문출장소            제주특별자치도 제주시 중앙로 386 2층   33.487872
# 159          삼호저축은행 제주지점               제주특별자치도 제주시 중앙로 535   33.475712
# 160   한국투자저축은행 제주여신전문출장소       제주특별자치도 제주시 노형로 407 노형타워 4층   33.485821
# 161  제이티친애저축은행 채권관리 제주센터         제주특별자치도 제주시 청사로 11 주연빌딩 3층  33.490092
#
#              경도      주소2
# 0    126.534321     이도이동
# 1    126.486661      노형동
# 2    126.524205     일도일동
# 3    126.526443     이도일동
# 4    126.481719      노형동
# ..          ...      ...
# 157  126.732440  남원읍 태흥리
# 158  126.539872     이도이동
# 159  126.545205     아라일동
# 160  126.478301      노형동
# 161  126.520159      도남동
#
# [162 rows x 5 columns]

# %%
#folium.Map() 함수 사용하여 지도 객체 생성하기
#df의 위도와 경도 열의 평균값인 위치에 해당하는 지도를 생성하고 확대 수준을 10으로 설정
map=folium.Map(location=[df.위도.mean(), df.경도.mean()], zoom_start=10)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fc108354863b2670e74a6469846b7b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fc108354863b2670e74a6469846b7b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1fc108354863b2670e74a6469846b7b0 = L.map(
#                 &quot;map_1fc108354863b2670e74a6469846b7b0&quot;,
#                 {
#                     center: [33.41831882865659, 126.52356282571124],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9247cd5169f21c7607ce8a3c5a7a4733 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_9247cd5169f21c7607ce8a3c5a7a4733.addTo(map_1fc108354863b2670e74a6469846b7b0);
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#제주시(blue)-서귀포시(green) 구분해서 folium.Marker
tiles = "http://mt0.google.com/vt/lyrs=m&hl=ko&x={x}&y={y}&z={z}" #구글지도 타일 설정
attr= "Google" #속성 설정
map = folium.Map(location=[df['위도'].mean(), df['경도'].mean()], #folium을 사용하여 지도 초기화
                 zoom_start=10, tiles=tiles, attr=attr)
for i in df.index: #df의 각 행을 반복
    if '제주시' in df.loc[i, '주소']:
        folium.Marker(
            location=[df.loc[i, '위도'], df.loc[i, '경도']],
            tooltip=df.loc[i, '은행명'], #마커에 마우스를 올렸을 때 표시되는 툴팁으로 병원명 표시
            popup=folium.Popup(df.loc[i, '주소'], max_width=200),
            icon=folium.Icon(color='green', icon='glyphicon-usd')
        ).add_to(map)
    else:
        folium.Marker(
            location=[df.loc[i, '위도'], df.loc[i, '경도']],
            tooltip=df.loc[i, '은행명'], #마커에 마우스를 올렸을 때 표시되는 툴팁으로 병원명 표시
            popup=folium.Popup(df.loc[i, '주소'], max_width=200),
            icon=folium.Icon(color='blue', icon='glyphicon-usd')
        ).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50b22a2bd46765b4edb219ef1fa114ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50b22a2bd46765b4edb219ef1fa114ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50b22a2bd46765b4edb219ef1fa114ca = L.map(
#                 &quot;map_50b22a2bd46765b4edb219ef1fa114ca&quot;,
#                 {
#                     center: [33.41831882865659, 126.52356282571124],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b0561d36b184834695166607041b1c6 = L.tileLayer(
#                 &quot;http://mt0.google.com/vt/lyrs=m\u0026hl=ko\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_0b0561d36b184834695166607041b1c6.addTo(map_50b22a2bd46765b4edb219ef1fa114ca);
#
#             var marker_b5b1077074e884f98a2b22856d82b23b = L.marker(
#                 [33.494593216571, 126.534320623238],
#                 {}
#             ).addTo(map_50b22a2bd46765b4edb219ef1fa114ca);
#
#
#             var icon_7c188641da543a1ed26a0d77ee5e6ddc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-usd&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b5b1077074e884f98a2b22856d82b23b.setIcon(icon_7c188641da543a1ed26a0d77ee5e6ddc);
#
#
#         var popup_3fb2f0481ee6bd5842d53b61f031499f = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_2c9537b60da62fcef65511d6b0122d64 = $(`&lt;div id=&quot;html_2c9537b60da62fcef65511d6b0122d64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; 제주특별자치도 제주시 남광북1길 1 제주법조타워 1,2층 &lt;/div&gt;`)[0];
#                 popup_3fb2f0481ee6bd5842d53b61f031499f.setContent(html_2c9537b60da62fcef65511d6b0122d64);
#
#
#
#         marker_b5b1077074e884f98a2b22856d82b23b.bindPopup(popup_3fb2f0481ee6bd5842d53b61f031499f)
#         ;
#
#
#
#
#             marker_b5b1077074e884f98a2b22856d82b23b.bindTooltip(
#                 `&lt;div&gt;
#                      KB국민은행 제주종합금융센터
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_88b40fefa6f1ad877004792623db76a2 = L.marker(
#                 [33.4815916076525, 126.48666080169],
#                 {}
#             ).addTo(map_50b22a2bd46765b4edb219ef1fa114ca);
#
#
#             var icon_10acc5d7c4858c1bb59bdc17ba6937c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-usd&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_88b40fefa6f1ad877004792623db76a2.setIcon(icon_10acc5d7c4858c1bb59bdc17ba6937c2);
#
#
#         var popup_61c20ef6c90904a58b3ed8fbe1a64e65 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_1b96f2eecd7ab522b7c8eb03984a11b9 = $(`&lt;div id=&quot;html_1b96f2eecd7ab522b7c8eb03984a11b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; 제주특별자치도 제주시 연북로 50 &lt;/div&gt;`)[0];
#                 popup_61c20ef6c90904a58b3ed8fbe1a64e65.setContent(html_1b96f2eecd7ab522b7c8eb03984a11b9);
#
#
#
#         marker_88b40fefa6f1ad877004792623db76a2.bindPopup(popup_61c20ef6c90904a58b3ed8fbe1a64e65)
#         ;
#
#
#
#
#             marker_88b40fefa6f1ad877004792623db76a2.bindTooltip(
#                 `&lt;div&gt;
#                      KB국민은행 연북로지점
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5a97103bbba8810705ea7768b9e6a12b = L.marker(
#                 [33.5129224625522, 126.524204690747],
#                 {}
#             ).addTo(map_50b22a2bd46765b4edb219ef1fa114ca);
#
#
#             var icon_671290d1a3943904ff0c31cae069b580 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon-usd&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5a97103bbba8810705ea7768b9e6a12b.setIcon(icon_671290d1a3943904ff0c31cae069b580);
#
#
#         var popup_1c2b3552c3804e97eb8bc6c52d9ca0b3 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_646c54e3f605b0a60786da321901013a = $(`&lt;div id=&quot;html_646c54e3f605b0a60786da321901013a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; 제주특별자치도 제주시 중앙로 58 &lt;/div&gt;`)[0];
#                 popup_1c2b3552c3804e97eb8bc6c52d9ca0b3.setContent(html_646c54e3f605b0a60786da321901013a);
#
#
#
#         marker_5a97103bbba8810705ea7768b9e6a12b.bindPopup(popup_1c2b3552c3804e97eb8bc6c52d9ca0b3)
#         ;
